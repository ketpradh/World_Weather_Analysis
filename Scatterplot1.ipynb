# %%
import pandas as pd
import numpy as np
import datetime

# %%
cities_to_load = "weather_data/cities.csv"
cities_data_df = pd.read_csv(cities_to_load)
cities_data_df
# Out:
#      City_ID          City Country                 Date    Lat     Lng  \
# 0          0        Kailua      US  2020-12-23 03:08:10  21.40 -157.74
# 1          1          Hilo      US  2020-12-23 03:08:10  19.73 -155.09
# 2          2  Longyearbyen      SJ  2020-12-23 03:08:11  78.22   15.64
# 3          3      Havelock      US  2020-12-23 03:08:11  34.88  -76.90
# 4          4    Codrington      AU  2020-12-23 03:08:11 -38.27  141.97
# ..       ...           ...     ...                  ...    ...     ...
# 565      565       Vikevag      NO  2020-12-23 03:10:31  59.10    5.70
# 566      566         Oliva      ES  2020-12-23 03:10:31  38.92   -0.12
# 567      567         Khani      GE  2020-12-23 03:10:31  41.96   42.96
# 568      568      Caldwell      US  2020-12-23 03:10:31  43.66 -116.69
# 569      569      Goderich      CA  2020-12-23 03:10:32  43.75  -81.72
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       82.40        65          20        8.05
# ...

# %%
cities_lat = cities_data_df["Lat"]
cities_max_temp = cities_data_df["Max Temp"]

# %%
cities_data_df.plot(["Lat"], ["Max Temp"],kind ="scatter")
# Out:
# <AxesSubplot:xlabel='[Lat]', ylabel='[Max Temp]'>
